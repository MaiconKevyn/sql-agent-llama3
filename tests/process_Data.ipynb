# %%
import pandas as pd

# %%
CID10_capitulos = pd.read_csv('../../txt2sql_claude/data/CID-10-CAPITULOS.CSV',sep=';', encoding='latin1')
CID10_capitulos.shape
# Out:
# (22, 6)

# %%
CID10_capitulos.head(20)
# Out:
#     NUMCAP CATINIC CATFIM                                          DESCRICAO  \
# 0        1     A00    B99  Capítulo I - Algumas doenças infecciosas e par...
# 1        2     C00    D48                 Capítulo II - Neoplasias [tumores]
# 2        3     D50    D89  Capítulo III  - Doenças do sangue e dos órgãos...
# 3        4     E00    E90  Capítulo IV - Doenças endócrinas, nutricionais...
# 4        5     F00    F99  Capítulo V - Transtornos mentais e comportamen...
# 5        6     G00    G99           Capítulo VI - Doenças do sistema nervoso
# 6        7     H00    H59            Capítulo VII - Doenças do olho e anexos
# 7        8     H60    H95  Capítulo VIII - Doenças do ouvido e da apófise...
# 8        9     I00    I99     Capítulo IX - Doenças do aparelho circulatório
# 9       10     J00    J99      Capítulo X - Doenças do aparelho respiratório
# 10      11     K00    K93        Capítulo XI - Doenças do aparelho digestivo
# ...

# %%
CID10_cat = pd.read_csv('../../txt2sql_claude/data/CID-10-CATEGORIAS.CSV',sep=';', encoding='latin1')
CID10_cat.shape
# Out:
# (2045, 7)

# %%
CID10_cat
# Out:
#       CAT CLASSIF                                          DESCRICAO  \
# 0     A00     NaN                                             Cólera
# 1     A01     NaN                       Febres tifóide e paratifóide
# 2     A02     NaN                    Outras infecções por Salmonella
# 3     A03     NaN                                         Shiguelose
# 4     A04     NaN           Outras infecções intestinais bacterianas
# ...   ...     ...                                                ...
# 2040  U80     NaN  Agente resistente à penicilina e antibióticos ...
# 2041  U81     NaN  Agente resistente à vancomicina e antibióticos...
# 2042  U88     NaN         Agente resistente a múltiplos antibióticos
# 2043  U89     NaN  Agente resistente a outros antibióticos e a an...
# 2044  U99     NaN                     CID 10ª Revisão não disponível
#
#                                             DESCRABREV REFER  EXCLUIDOS  \
# ...

# %%
CID10_subcat = pd.read_csv('../data/CID-10-SUBCATEGORIAS.CSV',sep=';', encoding='latin1')
CID10_subcat
# Out:
#       SUBCAT CLASSIF RESTRSEXO CAUSAOBITO  \
# 0       A000     NaN       NaN        NaN
# 1       A001     NaN       NaN        NaN
# 2       A009     NaN       NaN        NaN
# 3       A010     NaN       NaN        NaN
# 4       A011     NaN       NaN        NaN
# ...      ...     ...       ...        ...
# 12446   U818     NaN       NaN        NaN
# 12447    U88     NaN       NaN        NaN
# 12448   U898     NaN       NaN        NaN
# 12449   U899     NaN       NaN        NaN
# 12450    U99     NaN       NaN        NaN
#
#                                                DESCRICAO  \
# 0      Cólera devida a Vibrio cholerae 01, biótipo ch...
# 1      Cólera devida a Vibrio cholerae 01, biótipo El...
# 2                                Cólera não especificada
# 3                                          Febre tifóide
# 4                                    Febre paratifóide A
# ...                                                  ...
# ...
